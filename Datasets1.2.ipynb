# %%
import pickle

# %%
import pickle
model_object = "This represents your model object"
with open('/content/heart_model.pkl', 'wb') as f:
    pickle.dump(model_object, f)

# %%
import pickle
l = pickle.load(open('/content/heart_model.pkl','rb'))
print(l)
# Out:
# This represents your model object
