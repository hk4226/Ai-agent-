# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract

# %%
import matplotlib.pyplot as plt
ip = "/content/sddefault.jpg"
plt.imshow (Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(595.5), np.float64(255.5), np.float64(-0.5))

# %%
from re import I
img =Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extract text:",text)
# Out:
# Extract text: | Handwriting. _is_the_style of writing. As the
# ‘Computer _uses__different fonts for Display.
# ing text, similarly. each and every person. |
# thas_.a. different style of writing. _Handwrit-.
# ‘ing_can be simply described as _weriting
# With one's own hands._The style_of
#
# writing 18. unige_for_ every person. | |

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = ("gTTS, Handwriting. _is_the_style of writing. As the Computer usesdifferent fonts for Display. ing text, similarly. each and every person. thas_.a. different style of writing. Handwriting_can be simply described as _weriting With ones own hands._The style_of writing 18. unige_for_ every person.")

# %%
b = gTTS(text=a, lang='en')

# %%
b.save("hk.mp3")

# %%
Audio("hk.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input('Enter any text: ')
translated = t.translate(text,src='en',dest='te')
print(f"Translated text:{translated.text}")
# Out:
# Enter any text: cash
# Translated text:నగదు
